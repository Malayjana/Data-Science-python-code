# %% [markdown]
# Refer - https://seaborn.pydata.org/tutorial/function_overview.html

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Seaborn Datasets

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Seaborn Colour Palette

# %% [markdown]
# https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.color_palette('pastel')
# Out:
# [(0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098),
#  (0.7254901960784313, 0.9490196078431372, 0.9411764705882353)]

# %%
sns.color_palette("rocket" )
# Out:
# [(0.20973515, 0.09747934, 0.24238489),
#  (0.43860848, 0.12177004, 0.34119475),
#  (0.67824099, 0.09192342, 0.3504148),
#  (0.8833417, 0.19830556, 0.26014181),
#  (0.95381595, 0.46373781, 0.31769923),
#  (0.96516917, 0.70776351, 0.5606593)]

# %%
sns.color_palette("mako")
# Out:
# [(0.18195582, 0.11955283, 0.23136943),
#  (0.25307401, 0.23772973, 0.48316271),
#  (0.21607792, 0.39736958, 0.61948028),
#  (0.20344718, 0.56074869, 0.65649508),
#  (0.25187832, 0.71827158, 0.67872193),
#  (0.54578602, 0.8544913, 0.69848331)]

# %%
sns.color_palette('Set2')
# Out:
# [(0.4, 0.7607843137254902, 0.6470588235294118),
#  (0.9882352941176471, 0.5529411764705883, 0.3843137254901961),
#  (0.5529411764705883, 0.6274509803921569, 0.796078431372549),
#  (0.9058823529411765, 0.5411764705882353, 0.7647058823529411),
#  (0.6509803921568628, 0.8470588235294118, 0.32941176470588235),
#  (1.0, 0.8509803921568627, 0.1843137254901961),
#  (0.8980392156862745, 0.7686274509803922, 0.5803921568627451),
#  (0.7019607843137254, 0.7019607843137254, 0.7019607843137254)]

# %%
sns.set_palette('rocket')

# %%
sns.color_palette()
# Out:
# [(0.20973515, 0.09747934, 0.24238489),
#  (0.43860848, 0.12177004, 0.34119475),
#  (0.67824099, 0.09192342, 0.3504148),
#  (0.8833417, 0.19830556, 0.26014181),
#  (0.95381595, 0.46373781, 0.31769923),
#  (0.96516917, 0.70776351, 0.5606593)]

# %% [markdown]
# # Categorical Plot

# %% [markdown]
# <li> Focus on distributions using categorical data in reference to one of the numerical columns
# <li> Aggregate categorical data based on a function (mean is the default)
# <li> Estimate total bill amount based on sex
# <li> With estimator you can define functions to use other than the mean like those
# <li> provided by NumPy : median, std, var, cov or make your own functions

# %% [markdown]
# ### a. bar plot

# %%
df_used_cars = pd.read_csv("bar_chart_data.csv")
df_used_cars
# Out:
#            Brand  Cars Listings
# 0           Audi            419
# 1            BMW            636
# 2  Mercedes-Benz            820
# 3     Mitsubishi            306
# 4        Renault            438
# 5         Toyota            509
# 6     Volkswagen            875

# %%
pal = sns.color_palette("viridis")
sns.barplot(x="Brand",y="Cars Listings",data=df_used_cars, palette=pal)
plt.xticks(rotation = 90, fontsize = 10) 
plt.show()

# %% [markdown]
# ### b.Horizontal Barplot

# %%
pal = sns.color_palette("pastel")
sorted_df = df_used_cars.sort_values(by='Cars Listings', ascending=False)
sns.barplot(y=sorted_df["Brand"], x=sorted_df["Cars Listings"])
plt.xticks(rotation = 90, fontsize = 10) 
plt.show()

# %%
pal = sns.color_palette("Set2")
#sns.set_palette('winter')
sns.catplot(x="Brand", 
            y='Cars Listings',
            data=df_used_cars,
            kind="bar",
            palette=pal
           )
plt.xticks(rotation=90)
# Show plot
plt.show()

# %%
# Create count plot with region on the y-axis
sns.countplot(x="day", data=tips, 
              palette=pal,
              hue='sex'
             )

# Show plot
plt.show()

# %%
plt.figure(figsize = (2, 2)) 

sns.catplot(y="day", 
            data=tips,
            kind="count",
            hue="smoker",
            col='sex'
           )

# Show plot
plt.show()

# %% [markdown]
# #### b. Boxplot
#
# <li> A box plot allows you to compare different variables
# <li> The box shows the quartiles of the data. The bar in the middle is the median and
# <li> the box extends 1 standard deviation from the median
# <li> The whiskers extend to all the other data aside from the points that are considered to be outliers

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.catplot(x="day", 
            y="total_bill",
            data=tips, 
            kind="box",
            #hue='sex',
            palette=pal
           )

# Show plot
plt.show()

# %% [markdown]
# ### Strip Plot

# %%
sns.catplot(x ='day', y ='total_bill', data = tips,
               #hue ='sex',  
              kind='strip',
              palette = pal
           )
plt.show()

# %% [markdown]
# ### Swarm Plot

# %%
sns.catplot(x ='day', y ='total_bill', data = tips,
               #hue ='smoker',  
            kind='swarm',
            palette=pal
           )
plt.show()

# %% [markdown]
# ### Violin Plot

# %%
#my_pal = {"Thur": "g", "Fri": "b", "Sat":"m",'Sun':"r"}
sns.catplot(x="day", 
            y="total_bill",
            data=tips, 
            kind="violin",
            split=True,
            hue='sex',
            palette=pal
           )

# Show plot
plt.show()

# %% [markdown]
# # Input Data: Univariate (1D Series)

# %% [markdown]
# ## Distribution Plots

# %% [markdown]
# ### a. distribution plot
# <li> Provides a way to look at a univariate distribution. </li>
# <li> A univeriate distribution provides a distribution for one variable</li>
# <li> Kernal Density Estimation with a Histogram is provided</li>
# <li> kde=False removes the KDE</li>
# <li> Bins define how many buckets to divide the data up into between intervals</li>
# <li> For example put all profits between $10 and $20 in this bucket</li>

# %%
sns.distplot(tips['total_bill'], 
             bins=10,
            kde = False,
             )
sns.distplot(tips['tip'], 
             bins=10,
            kde = False,
             )
plt.show()

# %%
sns.kdeplot(tips['total_bill']
            )
sns.kdeplot(tips['tip']
            )
plt.show()

# %% [markdown]
# ### b. ecdf Plot

# %%
penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.ecdfplot(data=penguins, x="flipper_length_mm")
plt.show()

# %% [markdown]
# ### c. Rug Plot

# %% [markdown]
# <li> Plots a single column of datapoints in an array as sticks on an axis
# <li> With a rug plot you'll see a more dense number of lines where the amount is
# # most common.
# <li>This is like how a histogram is taller where values are more common

# %%
sns.rugplot(tips['tip'],palette='pastel', height=0.3)
# Out:
# <AxesSubplot:xlabel='tip'>

# %% [markdown]
# ### Styling

# %%
# You can set styling for your axes and grids
# white, darkgrid, whitegrid, dark, ticks
sns.set_style('whitegrid')

# You can use figure sizing from Matplotlib
plt.figure(figsize=(6,4))

# Change size of lables, lines and other elements to best fit
# how you will present your data (paper, talk, poster)
sns.set_context('paper', font_scale=1.8)

sns.scatterplot(x='total_bill', y='tip', data=tips)

# Get rid of spines
# You can turn of specific spines with right=True, left=True
# bottom=True, top=True
sns.despine(left=False, bottom=False)

# %% [markdown]
# # Relational Plots

# %% [markdown]
# ### a. Scatter Plot

# %%
sns.scatterplot(x='total_bill', 
              y='tip', 
              data=tips
             )
plt.show()

# %% [markdown]
# ## b. Lineplot

# %%
mpg = pd.read_csv('mpg.csv')
sns.lineplot(x="model_year", y="mpg",
            data=mpg,
            ci=None,
            hue="origin",
             marker='o'
            )

# Show plot
plt.show()

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %% [markdown]
# ## Relplots

# %% [markdown]
# ### a. Scatter Plot

# %%
tips

# %%
g=sns.relplot(x='total_bill', 
                y='tip', 
                data=tips, 
                kind = 'scatter',
                size = 'total_bill',
                style = 'time',
                hue = 'smoker',
                col='sex',
                #row='time'
               )
plt.show()

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
sns.set_palette('viridis')

# Create line plot
sns.relplot(x="model_year", y="mpg",
            data=mpg,
            kind='line',
            ci=None,
            hue="origin",
            col='origin',
            style="origin", 
            #markers='True'
           )

# Show plot
plt.show()

# %% [markdown]
# ## Matrix Plots

# %% [markdown]
# ### Pairplots

# %% [markdown]
# <li> Pair Plot plots relationships across the entire data frames numerical values
# <li> With hue you can pass in a categorical column and the charts will be colorized
# <li> You can use color maps from Matplotlib to define what colors to use
# <li> sns.pairplot(tips_df, hue='sex', palette='Blues')

# %%
sns.pairplot(tips, 
             palette='mako',
             hue='sex'
             )
plt.show()

# %% [markdown]
# <li> To create a heatmap with data you must have data set up as a matrix where variables
# are on the columns and rows
#
# <li> Correlation tells you how influential a variable is on the result
# <li> Colormaps - https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html

# %%
cr_df = sns.load_dataset('car_crashes')
cr_df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
cr_df.corr()
# Out:
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# speeding          -0.077675   -0.065928
# alcohol           -0.170612   -0.112547
# not_distracted    -0.174856   -0.075970
# no_previous       -0.156895   -0.006359
# ins_premium        1.000000    0.623116
# ins_losses         0.623116    1.000000

# %%
plt.figure(figsize=(8,6))
sns.set_context('paper', font_scale=1.4)

# So we see that n previous accident is heavily correlated with accidents, while the
# insurance premium is not
crash_mx = cr_df.corr()

# Create the heatmap, add annotations and a color map
sns.heatmap(crash_mx, 
            annot=True, 
            cmap='Blues'
           )
# Out:
# <AxesSubplot:>

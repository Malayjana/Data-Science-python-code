# %% [markdown]
# # Exploratory Data Analysis

# %%
#load the libraries
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("C:\\Users\\Neha Excelr\\DataSets\\data_clean.csv")
data
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
data=data.iloc[:,1:]
data
# Out:
#      Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     67     5    1  2010    67       S
# 1     36.0    118.0   8.0     72     5    2  2010    72       C
# 2     12.0    149.0  12.6     74     5    3  2010    74      PS
# 3     18.0    313.0  11.5     62     5    4  2010    62       S
# 4      NaN      NaN  14.3     56     5    5  2010    56       S
# ..     ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4     67     5    1  2010    67       C
# 154   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155    NaN    145.0  13.2     77     9   27  2010    77       S
# 156   14.0    191.0  14.3     75     9   28  2010    75       S
# 157   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
data.describe()
# Out:
#             Ozone     Solar.R        Wind         Day    Year        Temp
# count  120.000000  151.000000  158.000000  158.000000   158.0  158.000000
# mean    41.583333  185.403974    9.957595   16.006329  2010.0   77.727848
# std     32.620709   88.723103    3.511261    8.997166     0.0    9.377877
# min      1.000000    7.000000    1.700000    1.000000  2010.0   56.000000
# 25%     18.000000  119.000000    7.400000    8.000000  2010.0   72.000000
# 50%     30.500000  197.000000    9.700000   16.000000  2010.0   78.500000
# 75%     61.500000  257.000000   11.875000   24.000000  2010.0   84.000000
# max    168.000000  334.000000   20.700000   31.000000  2010.0   97.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Temp C   158 non-null    object
#  4   Month    158 non-null    object
#  5   Day      158 non-null    int64
#  6   Year     158 non-null    int64
#  7   Temp     158 non-null    int64
#  8   Weather  155 non-null    object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 11.2+ KB

# %%
#Data Structure 
print(type(data))
data.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (158, 9)

# %%
#data types
data.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Temp C      object
# Month       object
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
#To find the unique values in 'Temp C'
data['Temp C'].unique()
# Out:
# array(['67', '72', '74', '62', '56', '66', '65', '59', '61', '69', 'C',
#        '68', '58', '64', '57', '73', '81', '79', '76', '78', '84', '85',
#        '82', '87', '90', '93', '92', '80', '77', '75', '83', '88', '89',
#        '91', '86', '97', '94', '96', '71', '63', '70'], dtype=object)

# %%
#To find the unique values in 'Month'
data['Month'].unique()
# Out:
# array(['5', 'May', '6', '7', '8', '9'], dtype=object)

# %%
#Finding the row which has the invalid data type
data[data['Month']=='May']
#data['Month']=='May'
# Out:
#     Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 23   32.0     92.0  12.0     61   May   24  2010    61       C

# %%
#Replacing an invalid value with the appropriate value 
data['Month']=data['Month'].replace('May',5)
data['Month'].unique()
# Out:
# array(['5', 5, '6', '7', '8', '9'], dtype=object)

# %%
data[data['Temp C']=='C']
# Out:
#     Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 10    7.0      NaN   6.9      C     5   11  2010    74       C

# %%
data['Weather'].unique()
# Out:
# array(['S', 'C', 'PS', nan], dtype=object)

# %% [markdown]
# # Data Conversion

# %%
#errors=coerce will introduce NA values for non numeric data in the columns
data['Month']=pd.to_numeric(data['Month'],errors='coerce')
data['Temp C']=pd.to_numeric(data['Temp C'],errors='coerce')
data['Weather']=data['Weather'].astype('category')   
#data['Wind']=data['Wind'].astype('int64')

# %%
data['Month'].unique()
# Out:
# array([5, 6, 7, 8, 9], dtype=int64)

# %%
data['Temp C'].unique()
# Out:
# array([67., 72., 74., 62., 56., 66., 65., 59., 61., 69., nan, 68., 58.,
#        64., 57., 73., 81., 79., 76., 78., 84., 85., 82., 87., 90., 93.,
#        92., 80., 77., 75., 83., 88., 89., 91., 86., 97., 94., 96., 71.,
#        63., 70.])

# %%
data.dtypes
# Out:
# Ozone       float64
# Solar.R     float64
# Wind        float64
# Temp C      float64
# Month         int64
# Day           int64
# Year          int64
# Temp          int64
# Weather    category
# dtype: object

# %%
data1=data.copy()

# %% [markdown]
# The method .copy() is used here so that any changes made in new DataFrame don't get reflected in the original one

# %% [markdown]
# # Duplicates

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 153    False
# 154    False
# 155    False
# 156     True
# 157    False
# Length: 158, dtype: bool

# %%
#Print the duplicated rows
data[data.duplicated()]
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 156   14.0    191.0  14.3    75.0      9   28  2010    75       S

# %%
#To check which of the rows are duplicated
data[data['Solar.R']==191]
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 46    21.0    191.0  14.9    77.0      6   16  2010    77      PS
# 150   14.0    191.0  14.3    75.0      9   28  2010    75       S
# 156   14.0    191.0  14.3    75.0      9   28  2010    75       S

# %%
#Count of duplicated rows
data[data.duplicated()].shape
# Out:
# (1, 9)

# %%
data=data.drop_duplicates()

# %%
data.shape
# Out:
# (157, 9)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Ozone, Solar.R, Wind, Temp C, Month, Day, Year, Temp, Weather]
# Index: []

# %% [markdown]
# # Drop columns

# %%
data[['Temp C','Temp']].head(10)
# Out:
#    Temp C  Temp
# 0    67.0    67
# 1    72.0    72
# 2    74.0    74
# 3    62.0    62
# 4    56.0    56
# 5    66.0    66
# 6    65.0    65
# 7    59.0    59
# 8    61.0    61
# 9    69.0    69

# %%
#To check which row in 'Temp C' & 'Temp', have different values
data[data['Temp C']!=data['Temp']]
# Out:
#     Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 10    7.0      NaN   6.9     NaN      5   11  2010    74       C

# %%
data=data.drop('Temp C',axis=1)
#data.drop('Temp C',axis=1,inplace=True)

# %%
data
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4      5    1  2010    67       S
# 1     36.0    118.0   8.0      5    2  2010    72       C
# 2     12.0    149.0  12.6      5    3  2010    74      PS
# 3     18.0    313.0  11.5      5    4  2010    62       S
# 4      NaN      NaN  14.3      5    5  2010    56       S
# ..     ...      ...   ...    ...  ...   ...   ...     ...
# 152   20.0    223.0  11.5      9   30  2010    68       S
# 153   41.0    190.0   7.4      5    1  2010    67       C
# 154   30.0    193.0   6.9      9   26  2010    70      PS
# 155    NaN    145.0  13.2      9   27  2010    77       S
# 157   18.0    131.0   8.0      9   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
data['Year'].unique()
# Out:
# array([2010], dtype=int64)

# %%
data.drop('Year',axis=1,inplace=True)
data
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Temp Weather
# 0     41.0    190.0   7.4      5    1    67       S
# 1     36.0    118.0   8.0      5    2    72       C
# 2     12.0    149.0  12.6      5    3    74      PS
# 3     18.0    313.0  11.5      5    4    62       S
# 4      NaN      NaN  14.3      5    5    56       S
# ..     ...      ...   ...    ...  ...   ...     ...
# 152   20.0    223.0  11.5      9   30    68       S
# 153   41.0    190.0   7.4      5    1    67       C
# 154   30.0    193.0   6.9      9   26    70      PS
# 155    NaN    145.0  13.2      9   27    77       S
# 157   18.0    131.0   8.0      9   29    76       C
#
# [157 rows x 7 columns]

# %% [markdown]
# # Rename the columns

# %%
#rename the Solar column
data = data.rename({'Solar.R': 'Solar','Temp':'Temp_F'}, axis=1)

# %%
data
# Out:
#      Ozone  Solar  Wind  Month  Day  Temp_F Weather
# 0     41.0  190.0   7.4      5    1      67       S
# 1     36.0  118.0   8.0      5    2      72       C
# 2     12.0  149.0  12.6      5    3      74      PS
# 3     18.0  313.0  11.5      5    4      62       S
# 4      NaN    NaN  14.3      5    5      56       S
# ..     ...    ...   ...    ...  ...     ...     ...
# 152   20.0  223.0  11.5      9   30      68       S
# 153   41.0  190.0   7.4      5    1      67       C
# 154   30.0  193.0   6.9      9   26      70      PS
# 155    NaN  145.0  13.2      9   27      77       S
# 157   18.0  131.0   8.0      9   29      76       C
#
# [157 rows x 7 columns]

# %% [markdown]
# # Outlier Detection

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# histogram of Ozone
data['Ozone'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.hist(data['Ozone'])
# Out:
# (array([28., 36., 21.,  9., 11.,  7.,  3.,  2.,  1.,  1.]),
#  array([  1. ,  17.7,  34.4,  51.1,  67.8,  84.5, 101.2, 117.9, 134.6,
#         151.3, 168. ]),
#  <BarContainer object of 10 artists>)

# %%
#Box plot
data.boxplot(column=['Ozone'],grid=True)
# Out:
# <AxesSubplot:>

# %%
#Descriptive stat
data['Ozone'].describe()
# Out:
# count    119.000000
# mean      41.815126
# std       32.659249
# min        1.000000
# 25%       18.000000
# 50%       31.000000
# 75%       62.000000
# max      168.000000
# Name: Ozone, dtype: float64

# %%
data['Ozone'].quantile(0.99)
# Out:
# 132.6599999999999

# %%
#Interquartile Range
print('Interquartile Range',62-18)

#Upper Limit of Ozone
print('Upper Limit',62+1.5*(62-18))

#Lower Limit of Ozone
print('Lower Limit',18-1.5*(62-18))
# Out:
# Interquartile Range 44
# Upper Limit 128.0
# Lower Limit -48.0

# %%
data[data['Ozone']>128]
# Out:
#      Ozone  Solar  Wind  Month  Day  Temp_F Weather
# 61   135.0  269.0   4.1      7    1      84       S
# 116  168.0  238.0   3.4      8   25      81      PS

# %%
Ozone_Outliers=data[data['Ozone']>128]
Ozone_Outliers
# Out:
#      Ozone  Solar  Wind  Month  Day  Temp_F Weather
# 61   135.0  269.0   4.1      7    1      84       S
# 116  168.0  238.0   3.4      8   25      81      PS

# %%
#To check outliers in any categorical data
#If any category has only 1 frequency, we can consider that as an outlier.
data['Weather'].value_counts()
# Out:
# S     58
# C     49
# PS    47
# Name: Weather, dtype: int64

# %%
#Bar plot
data['Weather'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
data
# Out:
#      Ozone  Solar  Wind  Month  Day  Temp_F Weather
# 0     41.0  190.0   7.4      5    1      67       S
# 1     36.0  118.0   8.0      5    2      72       C
# 2     12.0  149.0  12.6      5    3      74      PS
# 3     18.0  313.0  11.5      5    4      62       S
# 4      NaN    NaN  14.3      5    5      56       S
# ..     ...    ...   ...    ...  ...     ...     ...
# 152   20.0  223.0  11.5      9   30      68       S
# 153   41.0  190.0   7.4      5    1      67       C
# 154   30.0  193.0   6.9      9   26      70      PS
# 155    NaN  145.0  13.2      9   27      77       S
# 157   18.0  131.0   8.0      9   29      76       C
#
# [157 rows x 7 columns]

# %%
#To check outliers in other variables
fig,axs=plt.subplots(1,3)
plt.boxplot(data['Wind'])
plt.boxplot(data['Solar'])
plt.boxplot(data['Temp_F'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19c94338b50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x19c94346130>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x19c94338880>],
#  'medians': [<matplotlib.lines.Line2D at 0x19c943466d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19c943469a0>],
#  'means': []}

# %%
fig,axs=plt.subplots(3,figsize=(15,15))
axs[0].boxplot(data['Wind'])
axs[1].boxplot(data['Solar'])
axs[2].boxplot(data['Temp_F'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19c9445fb50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x19c94469130>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x19c9445f880>],
#  'medians': [<matplotlib.lines.Line2D at 0x19c944696d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19c944699a0>],
#  'means': []}

# %% [markdown]
# # Missing Values and Imputation

# %% [markdown]
# If the dataset is small, and only 3-5% data is missing from a specific numerical column, then it will be ideal to replace the missing values with either mean or median
# - Mean: If the data is normally distributed
# - Median: If the data is skewed
#
# If more than 60-70% is missing, then it will be ideal to drop the column, because imputing so much data is neither possible, nor appropriate.
#
# If data is missing upto 5% to 40%, then used advanced techniques.
# Either use linear regression, decision trees, or discretization

# %%
(1-(data['Ozone'].count()/157))*100
# Out:
# 24.20382165605095

# %%
import seaborn as sns
cols = data.columns 
cols
# Out:
# Index(['Ozone', 'Solar', 'Wind', 'Month', 'Day', 'Temp_F', 'Weather'], dtype='object')

# %%
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(data[cols].isnull(),
            cmap=sns.color_palette(colours))
# Out:
# <AxesSubplot:>

# %%
colours = ['Blue','Yellow'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(data[cols].isnull(), cmap=sns.color_palette(colours))
# Out:
# <AxesSubplot:>

# %%
data.shape

# %%
data.isnull().sum()

# %%
print('The % of missing values in Ozone is', (38/157)*100)
print('The % of missing values in Solar is', (7/157)*100)
print('The % of missing values in Weather is', (3/157)*100)
# Out:
# The % of missing values in Ozone is 24.203821656050955
# The % of missing values in Solar is 4.45859872611465
# The % of missing values in Weather is 1.910828025477707

# %%
#To check if 'Solar.R' column data is skewed
data['Solar'].skew()
# Out:
# -0.4141167126969295

# %% [markdown]
# - Since only about 4.43% data is missing in 'Solar', we can replace the missing value with mean/median depending upon skewness in the data.
# - If data is skewed, then replace with median
# - If data is normally dstributed, then replace with mean
#
# -1 -------- -0.5 -------- 0 -------- 0.5 -------- 1
#
# If skewness value is closer to -0.4 or less, OR 0.4 or more, then replace missing values with Median.
# If skewness value is more closer to 0, then replace missing values with Mean.
#
# Also if more than 5% data is missing, then it is NOT ideal to replace with a single value,
# we should look for similar cases in the data to impute the missing values.
#
# Suppose we consider 'Solar' column to be helpful in determining the missing values in Ozone, we must bin the Ozone data, and find the mean value of solar grouped by these bins.
#
# But 'Solar' column also has some missing data, so we need to impute those first if we want to use the 'Solar' column to impute missing values in 'Ozone' column.

# %%
data['Solar'].hist(bins=8)

# %%
solar_median=data['Solar'].median()
print(solar_median)
solar_mean=data['Solar'].mean()
print(solar_mean)
# Out:
# 199.0
# 185.36666666666667

# %%
data['Solar'] = data['Solar'].fillna(solar_median)
data['Solar'].isnull().sum()
# Out:
# 0

# %%
#To check which rows have any missing value under any column
data[data.isnull().any(axis=1)]
# Out:
#      Ozone  Solar  Wind  Month  Day  Temp_F Weather
# 4      NaN  199.0  14.3      5    5      56       S
# 9      NaN  194.0   8.6      5   10      69       S
# 24     NaN   66.0  16.6      5   25      57      PS
# 25     NaN  266.0  14.9      5   26      58       C
# 26     NaN  199.0   8.0      5   27      57      PS
# 31     NaN  286.0   8.6      6    1      78       S
# 32     NaN  287.0   9.7      6    2      74       C
# 33     NaN  242.0  16.1      6    3      67      PS
# 34     NaN  186.0   9.2      6    4      84       C
# 35     NaN  220.0   8.6      6    5      85      PS
# 36     NaN  264.0  14.3      6    6      79       C
# 38     NaN  273.0   6.9      6    8      87       S
# 41     NaN  259.0  10.9      6   11      93       C
# 42     NaN  250.0   9.2      6   12      92      PS
# 44     NaN  332.0  13.8      6   14      80       S
# 45     NaN  322.0  11.5      6   15      79       C
# 51     NaN  150.0   6.3      6   21      77       S
# ...

# %%
data.isnull().sum()
# Out:
# Ozone      38
# Solar       0
# Wind        0
# Month       0
# Day         0
# Temp_F      0
# Weather     3
# dtype: int64

# %%
data.corr()
# Out:
#            Ozone     Solar      Wind     Month       Day    Temp_F
# Ozone   1.000000  0.345610 -0.590270  0.149594 -0.025465  0.694404
# Solar   0.345610  1.000000 -0.057709 -0.083788 -0.156243  0.256994
# Wind   -0.590270 -0.057709  1.000000 -0.170328  0.029900 -0.441228
# Month   0.149594 -0.083788 -0.170328  1.000000  0.041438  0.408060
# Day    -0.025465 -0.156243  0.029900  0.041438  1.000000 -0.122787
# Temp_F  0.694404  0.256994 -0.441228  0.408060 -0.122787  1.000000

# %%
data['Temp_F'].describe()
# Out:
# count    157.000000
# mean      77.745223
# std        9.405334
# min       56.000000
# 25%       72.000000
# 50%       79.000000
# 75%       84.000000
# max       97.000000
# Name: Temp_F, dtype: float64

# %%
data['Temp_F_Bin']=pd.cut(x=data['Temp_F'],bins=[55,60,65,70,85,90,95,100], right=True,
                                 labels=['a','b','c','d','e','f','g'])
data
# Out:
#      Ozone  Solar  Wind  Month  Day  Temp_F Weather Solar_Bin Temp_F_Bin
# 0     41.0  190.0   7.4      5    1      67       S         d          c
# 1     36.0  118.0   8.0      5    2      72       C         c          d
# 2     12.0  149.0  12.6      5    3      74      PS         c          d
# 3     18.0  313.0  11.5      5    4      62       S         g          b
# 4      NaN  199.0  14.3      5    5      56       S         d          a
# ..     ...    ...   ...    ...  ...     ...     ...       ...        ...
# 152   20.0  223.0  11.5      9   30      68       S         e          c
# 153   41.0  190.0   7.4      5    1      67       C         d          c
# 154   30.0  193.0   6.9      9   26      70      PS         d          c
# 155    NaN  145.0  13.2      9   27      77       S         c          d
# 157   18.0  131.0   8.0      9   29      76       C         c          d
#
# [157 rows x 9 columns]

# %%
data.groupby('Temp_F_Bin')['Ozone'].mean()
# Out:
# Temp_F_Bin
# a    11.000000
# b    15.700000
# c    24.466667
# d    36.015873
# e    73.176471
# f    91.875000
# g    80.000000
# Name: Ozone, dtype: float64

# %%
Ozone_Bins=pd.DataFrame(data['Ozone'].groupby(data['Temp_F_Bin']).mean())
Ozone_Bins
# Out:
#                 Ozone
# Temp_F_Bin
# a           11.000000
# b           15.700000
# c           24.466667
# d           36.015873
# e           73.176471
# f           91.875000
# g           80.000000

# %%
data['Ozone_Full'] = data['Ozone'].fillna(data.groupby('Temp_F_Bin')['Ozone'].transform('mean'))

# %%
data[data[['Ozone_Full','Ozone','Solar_Bin']].isnull().any(axis=1)]
# Out:
#      Ozone  Solar  Wind  Month  Day  Temp_F Weather Solar_Bin Temp_F_Bin  \
# 4      NaN  199.0  14.3      5    5      56       S         d          a
# 9      NaN  194.0   8.6      5   10      69       S         d          c
# 24     NaN   66.0  16.6      5   25      57      PS         b          a
# 25     NaN  266.0  14.9      5   26      58       C         f          a
# 26     NaN  199.0   8.0      5   27      57      PS         d          a
# 31     NaN  286.0   8.6      6    1      78       S         f          d
# 32     NaN  287.0   9.7      6    2      74       C         f          d
# 33     NaN  242.0  16.1      6    3      67      PS         e          c
# 34     NaN  186.0   9.2      6    4      84       C         d          d
# 35     NaN  220.0   8.6      6    5      85      PS         e          d
# 36     NaN  264.0  14.3      6    6      79       C         f          d
# 38     NaN  273.0   6.9      6    8      87       S         f          e
# ...

# %%
data.isnull().sum()
# Out:
# Ozone         38
# Solar          0
# Wind           0
# Month          0
# Day            0
# Temp_F         0
# Weather        3
# Solar_Bin      0
# Temp_F_Bin     0
# Ozone_Full     0
# dtype: int64

# %%
data.drop('Ozone',axis=1,inplace=True)

# %%
data.rename({'Ozone_Full':'Ozone'},axis=1,inplace=True)
data
# Out:
#      Solar  Wind  Month  Day  Temp_F Weather Solar_Bin Temp_F_Bin      Ozone
# 0    190.0   7.4      5    1      67       S         d          c  41.000000
# 1    118.0   8.0      5    2      72       C         c          d  36.000000
# 2    149.0  12.6      5    3      74      PS         c          d  12.000000
# 3    313.0  11.5      5    4      62       S         g          b  18.000000
# 4    199.0  14.3      5    5      56       S         d          a  11.000000
# ..     ...   ...    ...  ...     ...     ...       ...        ...        ...
# 152  223.0  11.5      9   30      68       S         e          c  20.000000
# 153  190.0   7.4      5    1      67       C         d          c  41.000000
# 154  193.0   6.9      9   26      70      PS         d          c  30.000000
# 155  145.0  13.2      9   27      77       S         c          d  36.015873
# 157  131.0   8.0      9   29      76       C         c          d  18.000000
#
# [157 rows x 9 columns]

# %%
data.drop('Solar_Bin',axis=1,inplace=True)

# %%
data.isnull().sum()
# Out:
# Solar         0
# Wind          0
# Month         0
# Day           0
# Temp_F        0
# Weather       3
# Temp_F_Bin    0
# Ozone         0
# dtype: int64

# %%
data.groupby('Weather')['Temp_F'].mean()
# Out:
# Weather
# C     77.734694
# PS    76.872340
# S     78.120690
# Name: Temp_F, dtype: float64

# %%
data['Weather'].mode()

# %%
data[data['Weather'].isnull()]
# Out:
#     Solar  Wind  Month  Day  Temp_F Weather Temp_F_Bin  Ozone
# 87   82.0  12.0      7   27      86     NaN          e   52.0
# 93   24.0  13.8      8    2      81     NaN          d    9.0
# 95  199.0   6.9      8    4      86     NaN          e   78.0

# %%
data['Weather']=data['Weather'].fillna('S')

# %%
data.isnull().sum()
# Out:
# Solar         0
# Wind          0
# Month         0
# Day           0
# Temp_F        0
# Weather       0
# Temp_F_Bin    0
# Ozone         0
# dtype: int64

# %%
#data_cleaned=pd.concat([data_cleaned,obj_columns],axis=1)

# %% [markdown]
# # Scatter plot and Correlation analysis

# %%
# Seaborn visualization library
import seaborn as sns
# Create the default pairplot
sns.pairplot(data)

# %%
#Correlation
data.corr()

# -1 ----------- -0.5 ----------- 0 ----------- 0.5 ----------- 1 

#Correlation is always between -1 to +1
#-1 to -0.5 & +0.5 to +1 is strong correlationship
#-0.5 to 0 & 0 to 0.5 is moderate correlationship
#Values very close to 0 indicate no correlationship
# Out:
#            Solar      Wind     Month       Day    Temp_F     Ozone
# Solar   1.000000 -0.057709 -0.083788 -0.156243  0.256994  0.320289
# Wind   -0.057709  1.000000 -0.170328  0.029900 -0.441228 -0.515624
# Month  -0.083788 -0.170328  1.000000  0.041438  0.408060  0.176829
# Day    -0.156243  0.029900  0.041438  1.000000 -0.122787 -0.055348
# Temp_F  0.256994 -0.441228  0.408060 -0.122787  1.000000  0.712298
# Ozone   0.320289 -0.515624  0.176829 -0.055348  0.712298  1.000000

# %% [markdown]
# # Transformations

# %% [markdown]
# #### Dummy Variable

# %% [markdown]
# # Creating dummy variable for Weather column
#
# ## Dummy variable creation
# ## One Hot Encoding

# %%
data
# Out:
#      Solar  Wind  Month  Day  Temp_F Weather Temp_F_Bin      Ozone
# 0    190.0   7.4      5    1      67       S          c  41.000000
# 1    118.0   8.0      5    2      72       C          d  36.000000
# 2    149.0  12.6      5    3      74      PS          d  12.000000
# 3    313.0  11.5      5    4      62       S          b  18.000000
# 4    199.0  14.3      5    5      56       S          a  11.000000
# ..     ...   ...    ...  ...     ...     ...        ...        ...
# 152  223.0  11.5      9   30      68       S          c  20.000000
# 153  190.0   7.4      5    1      67       C          c  41.000000
# 154  193.0   6.9      9   26      70      PS          c  30.000000
# 155  145.0  13.2      9   27      77       S          d  36.015873
# 157  131.0   8.0      9   29      76       C          d  18.000000
#
# [157 rows x 8 columns]

# %%
#We will drop 'Solar_Bin' column as it was created only for missing value imputation
data=data.drop('Temp_F_Bin',axis=1)
data
# Out:
#      Solar  Wind  Month  Day  Temp_F Weather      Ozone
# 0    190.0   7.4      5    1      67       S  41.000000
# 1    118.0   8.0      5    2      72       C  36.000000
# 2    149.0  12.6      5    3      74      PS  12.000000
# 3    313.0  11.5      5    4      62       S  18.000000
# 4    199.0  14.3      5    5      56       S  11.000000
# ..     ...   ...    ...  ...     ...     ...        ...
# 152  223.0  11.5      9   30      68       S  20.000000
# 153  190.0   7.4      5    1      67       C  41.000000
# 154  193.0   6.9      9   26      70      PS  30.000000
# 155  145.0  13.2      9   27      77       S  36.015873
# 157  131.0   8.0      9   29      76       C  18.000000
#
# [157 rows x 7 columns]

# %%
data=pd.get_dummies(data,columns=['Weather'])
data
# Out:
#      Solar  Wind  Month  Day  Temp_F      Ozone  Weather_C  Weather_PS  \
# 0    190.0   7.4      5    1      67  41.000000          0           0
# 1    118.0   8.0      5    2      72  36.000000          1           0
# 2    149.0  12.6      5    3      74  12.000000          0           1
# 3    313.0  11.5      5    4      62  18.000000          0           0
# 4    199.0  14.3      5    5      56  11.000000          0           0
# ..     ...   ...    ...  ...     ...        ...        ...         ...
# 152  223.0  11.5      9   30      68  20.000000          0           0
# 153  190.0   7.4      5    1      67  41.000000          1           0
# 154  193.0   6.9      9   26      70  30.000000          0           1
# 155  145.0  13.2      9   27      77  36.015873          0           0
# 157  131.0   8.0      9   29      76  18.000000          1           0
#
#      Weather_S
# 0            1
# 1            0
# 2            0
# 3            1
# 4            1
# ..         ...
# ...

# %%
print(data.min())
print(data.max())
print(data.mean())
print(data.std())
# Out:
# Solar          7.0
# Wind           1.7
# Month          5.0
# Day            1.0
# Temp_F        56.0
# Ozone          1.0
# Weather_C      0.0
# Weather_PS     0.0
# Weather_S      0.0
# dtype: float64
# Solar         334.0
# Wind           20.7
# Month           9.0
# Day            31.0
# Temp_F         97.0
# Ozone         168.0
# Weather_C       1.0
# Weather_PS      1.0
# Weather_S       1.0
# dtype: float64
# Solar         185.974522
# Wind            9.929936
# Month           7.019108
# Day            15.929936
# Temp_F         77.745223
# Ozone          41.760252
# Weather_C       0.312102
# Weather_PS      0.299363
# Weather_S       0.388535
# dtype: float64
# Solar         87.044783
# Wind           3.505188
# Month          1.434338
# Day            8.974404
# Temp_F         9.405334
# Ozone         30.390307
# Weather_C      0.464834
# Weather_PS     0.459445
# Weather_S      0.488977
# dtype: float64

# %%
data.describe()

# %% [markdown]
# # Normalization of the data
# # Scaling of Data

# %%
#Normalization of the data
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

# %%
data
# Out:
#      Solar  Wind  Month  Day  Temp_F      Ozone  Weather_C  Weather_PS  \
# 0    190.0   7.4      5    1      67  41.000000          0           0
# 1    118.0   8.0      5    2      72  36.000000          1           0
# 2    149.0  12.6      5    3      74  12.000000          0           1
# 3    313.0  11.5      5    4      62  18.000000          0           0
# 4    199.0  14.3      5    5      56  11.000000          0           0
# ..     ...   ...    ...  ...     ...        ...        ...         ...
# 152  223.0  11.5      9   30      68  20.000000          0           0
# 153  190.0   7.4      5    1      67  41.000000          1           0
# 154  193.0   6.9      9   26      70  30.000000          0           1
# 155  145.0  13.2      9   27      77  36.015873          0           0
# 157  131.0   8.0      9   29      76  18.000000          1           0
#
#      Weather_S
# 0            1
# 1            0
# 2            0
# 3            1
# 4            1
# ..         ...
# ...

# %%
#MinMax Scalar
#(Data_Value - Minimum Value) / Range of the Data

# %%
array1=data.values
array1
# Out:
# array([[190. ,   7.4,   5. , ...,   0. ,   0. ,   1. ],
#        [118. ,   8. ,   5. , ...,   1. ,   0. ,   0. ],
#        [149. ,  12.6,   5. , ...,   0. ,   1. ,   0. ],
#        ...,
#        [193. ,   6.9,   9. , ...,   0. ,   1. ,   0. ],
#        [145. ,  13.2,   9. , ...,   0. ,   0. ,   1. ],
#        [131. ,   8. ,   9. , ...,   1. ,   0. ,   0. ]])

# %%
scaler = MinMaxScaler(feature_range=(0,1))
rescaledX = scaler.fit_transform(array1)

# %%
rescaledX
# Out:
# array([[0.55963303, 0.3       , 0.        , ..., 0.        , 0.        ,
#         1.        ],
#        [0.33944954, 0.33157895, 0.        , ..., 1.        , 0.        ,
#         0.        ],
#        [0.43425076, 0.57368421, 0.        , ..., 0.        , 1.        ,
#         0.        ],
#        ...,
#        [0.56880734, 0.27368421, 1.        , ..., 0.        , 1.        ,
#         0.        ],
#        [0.42201835, 0.60526316, 1.        , ..., 0.        , 0.        ,
#         1.        ],
#        [0.37920489, 0.33157895, 1.        , ..., 1.        , 0.        ,
#         0.        ]])

# %%
#transformed data
set_printoptions(precision=2)
print(rescaledX)
# Out:
# [[0.56 0.3  0.   ... 0.   0.   1.  ]
#  [0.34 0.33 0.   ... 1.   0.   0.  ]
#  [0.43 0.57 0.   ... 0.   1.   0.  ]
#  ...
#  [0.57 0.27 1.   ... 0.   1.   0.  ]
#  [0.42 0.61 1.   ... 0.   0.   1.  ]
#  [0.38 0.33 1.   ... 1.   0.   0.  ]]

# %%
# Standardize data (0 mean, 1 stdev)
from sklearn.preprocessing import StandardScaler

# %%
#(Data Value - Mean of the column) / Stdev of the Column

# %%
#scaler = StandardScaler().fit(array1)
#rescaledX = scaler.transform(array1)

scaler=StandardScaler()
rescaledX=scaler.fit_transform(array1)
rescaledX
# summarize transformed data
#set_printoptions(precision=2)
# Out:
# array([[ 0.05, -0.72, -1.41, ..., -0.67, -0.65,  1.25],
#        [-0.78, -0.55, -1.41, ...,  1.48, -0.65, -0.8 ],
#        [-0.43,  0.76, -1.41, ..., -0.67,  1.53, -0.8 ],
#        ...,
#        [ 0.08, -0.87,  1.39, ..., -0.67,  1.53, -0.8 ],
#        [-0.47,  0.94,  1.39, ..., -0.67, -0.65,  1.25],
#        [-0.63, -0.55,  1.39, ...,  1.48, -0.65, -0.8 ]])

# %% [markdown]
# # Speed up the EDA process

# %%
#pip (preferred installer program)
#!pip install pandas_profiling
#!pip install sweetviz

# %%
pip install pandas_profiling

# %%
import pandas_profiling as pp
#EDA_report= pp.ProfileReport(data)
#EDA_report

# %%
#To create an HTML format report
EDA_report.to_file(output_file='report.html')

# %%
sweet_report = sv.analyze(data)
sweet_report.show_html('weather_report.html')

# %%
# import pandas
import pandas as pd
 
# create data frame
df = pd.DataFrame({'First Name': ["Mukul", "Rohan", "Mayank",
                                  "Vedansh", "Krishna"],
                    
                   'Location': ["Saharanpur", "Rampur", "Agra",
                                "Saharanpur", "Noida"],
                    
                   'Pay': [56000.0, 55000.0, 61000.0, 45000.0, 62000.0]})
 
# print original data frame
display(df)
 
# create a dictionary
# key = old name
# value = new name
dict = {'First Name': 'Name',
        'Location': 'City',
        'Pay': 'Salary'}
 
# call rename () method
df.rename(columns=dict,
          inplace=True)
 
# print Data frame after rename columns
display(df)
